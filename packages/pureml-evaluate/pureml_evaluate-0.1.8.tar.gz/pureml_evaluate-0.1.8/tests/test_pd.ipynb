# %%
import pureml_evaluate

# %%
pureml_evaluate.__version__
# Out:
# '0.1.4.1'

# %%
from pureml_evaluate.evaluators.evaluator import Evaluator

# %%
import joblib
y_true = joblib.load("y_test.pkl").values
y_pred = joblib.load("y_pred.pkl")
sensitive_features = joblib.load("sensitive_features.pkl")

# %%
sensitive_features
# Out:
# 9407       male
# 2311       male
# 22633    female
# 9255     female
# 8901     female
#           ...
# 26220    female
# 18170      male
# 25486    female
# 3113     female
# 27486      male
# Name: SEX, Length: 10500, dtype: category
# Categories (2, object): ['male', 'female']

# %%
print(sensitive_features.ndim, sensitive_features.shape)
# Out:
# 1 (10500,)

# %%
import random
import numpy as np

values = ['Indian', 'African', 'American']

list_length = sensitive_features.shape[0]
full_list = values * (list_length // len(values))
full_list += values[:list_length % len(values)]
random.shuffle(full_list)

full_list = np.array(full_list)
print(full_list.shape)
# Print the resulting list
# print(full_list)
# Out:
# (10500,)

# %%
import pandas as pd
s_feat = pd.concat([sensitive_features.reset_index(drop=True), pd.DataFrame(full_list, columns=['Race'])], axis=1)

# %%
from pureml_evaluate.evaluators.evaluator import eval


values = eval(y_true=y_true, 
              y_pred=y_pred, 
              sensitive_features=s_feat, 
              evaluators=['classification', 'fairness'])
values
# Out:
# 2 (10500, 2) ['SEX', 'Race']
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# evaluate subsets 0 2
# 1 (6330,) ['sensitive_column_1']
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# 1 (4170,) ['sensitive_column_1']
# evaluate subsets 1 3
# 1 (3500,) ['sensitive_column_1']
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /media/vamsidhar/HDD/aztlan/engageml/repos/PureML/packages/pureml_evaluate/.venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1802: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# 1 (3500,) ['sensitive_column_1']
# 1 (3500,) ['sensitive_column_1']
# {'complete': {'performance': {'accuracy': {'value': 0.7971428571428572},
#    'precision': {'value': 0.5270081164287713},
#    'recall': {'value': 0.8105897546276367},
#    'f1': {'value': 0.6387381275440978},
#    'balanced_accuracy_score': {'value': 0.801956244563421},
#    'top_k_accuracy_score': {'value': 1.0},
#    'log_loss': {'value': 7.311712544649479},
#    'average_precision_score': {'value': 0.46909214168753266},
#    'roc_auc': {'value': 0.8019562445634209},
#    'brier_score_loss': {'value': 0.20285714285714285}},
#   'fairness': {'SEX': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.058073351745144164},
#     'demographic_parity_ratio': {'value': 0.8401720362840163},
#     'equalized_odds_difference': {'value': 0.12304095990295033},
#     'equalized_odds_ratio': {'value': 0.5170472645574502},
#     'true_positive_parity': {'value': 0.11047349698537057},
#     'false_positive_parity': {'value': 0.12304095990295033},
#     'predictive_value_parity': {'value': 0.2210242836162437}},
#    'Race': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.013714285714285734},
#     'demographic_parity_ratio': {'value': 0.9604612850082371},
#     'equalized_odds_difference': {'value': 0.015959537151590153},
#     'equalized_odds_ratio': {'value': 0.9254673161889656},
#     'true_positive_parity': {'value': 0.00374841190071018},
#     'false_positive_parity': {'value': 0.015959537151590153},
#     'predictive_value_parity': {'value': 0.01542750246551805}}}},
#  'subsets': {'SEX': {'female': {'performance': {'accuracy': {'value': 0.7492890995260664},
#      'precision': {'value': 0.4482608695652174},
#      'recall': {'value': 0.7642698295033358},
#      'f1': {'value': 0.5650863250205536},
#      'balanced_accuracy_score': {'value': 0.7547508553258497},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 9.036536797555911},
#      'average_precision_score': {'value': 0.3928292251802703},
#      'roc_auc': {'value': 0.7547508553258497},
#      'brier_score_loss': {'value': 0.25071090047393363}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7547508553258497},
#       'balanced_acc_error': {'value': 0.01284020550193306},
#       'selection_rate': {'value': 0.36334913112164297},
#       'false_positive_rate': {'value': 0.2547681188516362},
#       'false_positive_error': {'value': 0.01210085490514792},
#       'false_negative_rate': {'value': 0.2357301704966642},
#       'false_negative_error': {'value': 0.022650669303401295},
#       'true_positive_rate': {'value': 0.7642698295033358},
#       'true_negative_rate': {'value': 0.7452318811483638},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'male': {'performance': {'accuracy': {'value': 0.8697841726618705},
#      'precision': {'value': 0.6692851531814611},
#      'recall': {'value': 0.8747433264887063},
#      'f1': {'value': 0.7583444592790386},
#      'balanced_accuracy_score': {'value': 0.8715080837700102},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 4.693454146352666},
#      'average_precision_score': {'value': 0.6147093159876752},
#      'roc_auc': {'value': 0.8715080837700102},
#      'brier_score_loss': {'value': 0.1302158273381295}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8715080837700102},
#       'balanced_acc_error': {'value': 0.011933454584385012},
#       'selection_rate': {'value': 0.3052757793764988},
#       'false_positive_rate': {'value': 0.13172715894868586},
#       'false_positive_error': {'value': 0.011725151341348909},
#       'false_negative_rate': {'value': 0.12525667351129363},
#       'false_negative_error': {'value': 0.020788222129195715},
#       'true_positive_rate': {'value': 0.8747433264887063},
#       'true_negative_rate': {'value': 0.8682728410513142},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}},
#   'Race': {'African': {'performance': {'accuracy': {'value': 0.804},
#      'precision': {'value': 0.5360205831903945},
#      'recall': {'value': 0.8116883116883117},
#      'f1': {'value': 0.6456611570247933},
#      'balanced_accuracy_score': {'value': 0.8067599067599067},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.064556064266962},
#      'average_precision_score': {'value': 0.47651021362856694},
#      'roc_auc': {'value': 0.8067599067599068},
#      'brier_score_loss': {'value': 0.196}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8067599067599067},
#       'balanced_acc_error': {'value': 0.015701768766110395},
#       'selection_rate': {'value': 0.33314285714285713},
#       'false_positive_rate': {'value': 0.19816849816849816},
#       'false_positive_error': {'value': 0.014953181822692408},
#       'false_negative_rate': {'value': 0.18831168831168832},
#       'false_negative_error': {'value': 0.027614932969592762},
#       'true_positive_rate': {'value': 0.8116883116883117},
#       'true_negative_rate': {'value': 0.8018315018315019},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'American': {'performance': {'accuracy': {'value': 0.7908571428571428},
#      'precision': {'value': 0.5205930807248764},
#      'recall': {'value': 0.8081841432225064},
#      'f1': {'value': 0.6332665330661322},
#      'balanced_accuracy_score': {'value': 0.7970280539512091},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.538272651666788},
#      'average_precision_score': {'value': 0.46359221577034226},
#      'roc_auc': {'value': 0.7970280539512091},
#      'brier_score_loss': {'value': 0.20914285714285713}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7970280539512091},
#       'balanced_acc_error': {'value': 0.015806603552970235},
#       'selection_rate': {'value': 0.34685714285714286},
#       'false_positive_rate': {'value': 0.2141280353200883},
#       'false_positive_error': {'value': 0.015422117557001415},
#       'false_negative_rate': {'value': 0.1918158567774936},
#       'false_negative_error': {'value': 0.027596252527854463},
#       'true_positive_rate': {'value': 0.8081841432225064},
#       'true_negative_rate': {'value': 0.7858719646799117},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'Indian': {'performance': {'accuracy': {'value': 0.7965714285714286},
#      'precision': {'value': 0.5247275775356245},
#      'recall': {'value': 0.8119325551232166},
#      'f1': {'value': 0.6374745417515275},
#      'balanced_accuracy_score': {'value': 0.8020820708924987},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.33230891801469},
#      'average_precision_score': {'value': 0.46747197420068676},
#      'roc_auc': {'value': 0.8020820708924987},
#      'brier_score_loss': {'value': 0.20342857142857143}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8020820708924987},
#       'balanced_acc_error': {'value': 0.015752334045429407},
#       'selection_rate': {'value': 0.34085714285714286},
#       'false_positive_rate': {'value': 0.20776841333821913},
#       'false_positive_error': {'value': 0.015221944778951014},
#       'false_negative_rate': {'value': 0.1880674448767834},
#       'false_negative_error': {'value': 0.027583265010903687},
#       'true_positive_rate': {'value': 0.8119325551232166},
#       'true_negative_rate': {'value': 0.7922315866617808},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}}}}

# %%
import json



with open("values_pd.json", "w",) as out_file:
    json.dump(values, out_file)

# %%
with open("values_pd.json") as temp:
    v = json.load(temp)
    # v = json.loads(v)

print(type(v))
v
# Out:
# <class 'dict'>
# {'complete': {'performance': {'accuracy': {'value': 0.7971428571428572},
#    'precision': {'value': 0.5270081164287713},
#    'recall': {'value': 0.8105897546276367},
#    'f1': {'value': 0.6387381275440978},
#    'balanced_accuracy_score': {'value': 0.801956244563421},
#    'top_k_accuracy_score': {'value': 1.0},
#    'log_loss': {'value': 7.311712544649479},
#    'average_precision_score': {'value': 0.46909214168753266},
#    'roc_auc': {'value': 0.8019562445634209},
#    'brier_score_loss': {'value': 0.20285714285714285}},
#   'fairness': {'SEX': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.058073351745144164},
#     'demographic_parity_ratio': {'value': 0.8401720362840163},
#     'equalized_odds_difference': {'value': 0.12304095990295033},
#     'equalized_odds_ratio': {'value': 0.5170472645574502},
#     'true_positive_parity': {'value': 0.11047349698537057},
#     'false_positive_parity': {'value': 0.12304095990295033},
#     'predictive_value_parity': {'value': 0.2210242836162437}},
#    'Race': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.013714285714285734},
#     'demographic_parity_ratio': {'value': 0.9604612850082371},
#     'equalized_odds_difference': {'value': 0.015959537151590153},
#     'equalized_odds_ratio': {'value': 0.9254673161889656},
#     'true_positive_parity': {'value': 0.00374841190071018},
#     'false_positive_parity': {'value': 0.015959537151590153},
#     'predictive_value_parity': {'value': 0.01542750246551805}}}},
#  'subsets': {'SEX': {'female': {'performance': {'accuracy': {'value': 0.7492890995260664},
#      'precision': {'value': 0.4482608695652174},
#      'recall': {'value': 0.7642698295033358},
#      'f1': {'value': 0.5650863250205536},
#      'balanced_accuracy_score': {'value': 0.7547508553258497},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 9.036536797555911},
#      'average_precision_score': {'value': 0.3928292251802703},
#      'roc_auc': {'value': 0.7547508553258497},
#      'brier_score_loss': {'value': 0.25071090047393363}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7547508553258497},
#       'balanced_acc_error': {'value': 0.01284020550193306},
#       'selection_rate': {'value': 0.36334913112164297},
#       'false_positive_rate': {'value': 0.2547681188516362},
#       'false_positive_error': {'value': 0.01210085490514792},
#       'false_negative_rate': {'value': 0.2357301704966642},
#       'false_negative_error': {'value': 0.022650669303401295},
#       'true_positive_rate': {'value': 0.7642698295033358},
#       'true_negative_rate': {'value': 0.7452318811483638},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'male': {'performance': {'accuracy': {'value': 0.8697841726618705},
#      'precision': {'value': 0.6692851531814611},
#      'recall': {'value': 0.8747433264887063},
#      'f1': {'value': 0.7583444592790386},
#      'balanced_accuracy_score': {'value': 0.8715080837700102},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 4.693454146352666},
#      'average_precision_score': {'value': 0.6147093159876752},
#      'roc_auc': {'value': 0.8715080837700102},
#      'brier_score_loss': {'value': 0.1302158273381295}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8715080837700102},
#       'balanced_acc_error': {'value': 0.011933454584385012},
#       'selection_rate': {'value': 0.3052757793764988},
#       'false_positive_rate': {'value': 0.13172715894868586},
#       'false_positive_error': {'value': 0.011725151341348909},
#       'false_negative_rate': {'value': 0.12525667351129363},
#       'false_negative_error': {'value': 0.020788222129195715},
#       'true_positive_rate': {'value': 0.8747433264887063},
#       'true_negative_rate': {'value': 0.8682728410513142},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}},
#   'Race': {'African': {'performance': {'accuracy': {'value': 0.804},
#      'precision': {'value': 0.5360205831903945},
#      'recall': {'value': 0.8116883116883117},
#      'f1': {'value': 0.6456611570247933},
#      'balanced_accuracy_score': {'value': 0.8067599067599067},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.064556064266962},
#      'average_precision_score': {'value': 0.47651021362856694},
#      'roc_auc': {'value': 0.8067599067599068},
#      'brier_score_loss': {'value': 0.196}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8067599067599067},
#       'balanced_acc_error': {'value': 0.015701768766110395},
#       'selection_rate': {'value': 0.33314285714285713},
#       'false_positive_rate': {'value': 0.19816849816849816},
#       'false_positive_error': {'value': 0.014953181822692408},
#       'false_negative_rate': {'value': 0.18831168831168832},
#       'false_negative_error': {'value': 0.027614932969592762},
#       'true_positive_rate': {'value': 0.8116883116883117},
#       'true_negative_rate': {'value': 0.8018315018315019},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'American': {'performance': {'accuracy': {'value': 0.7908571428571428},
#      'precision': {'value': 0.5205930807248764},
#      'recall': {'value': 0.8081841432225064},
#      'f1': {'value': 0.6332665330661322},
#      'balanced_accuracy_score': {'value': 0.7970280539512091},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.538272651666788},
#      'average_precision_score': {'value': 0.46359221577034226},
#      'roc_auc': {'value': 0.7970280539512091},
#      'brier_score_loss': {'value': 0.20914285714285713}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7970280539512091},
#       'balanced_acc_error': {'value': 0.015806603552970235},
#       'selection_rate': {'value': 0.34685714285714286},
#       'false_positive_rate': {'value': 0.2141280353200883},
#       'false_positive_error': {'value': 0.015422117557001415},
#       'false_negative_rate': {'value': 0.1918158567774936},
#       'false_negative_error': {'value': 0.027596252527854463},
#       'true_positive_rate': {'value': 0.8081841432225064},
#       'true_negative_rate': {'value': 0.7858719646799117},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'Indian': {'performance': {'accuracy': {'value': 0.7965714285714286},
#      'precision': {'value': 0.5247275775356245},
#      'recall': {'value': 0.8119325551232166},
#      'f1': {'value': 0.6374745417515275},
#      'balanced_accuracy_score': {'value': 0.8020820708924987},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.33230891801469},
#      'average_precision_score': {'value': 0.46747197420068676},
#      'roc_auc': {'value': 0.8020820708924987},
#      'brier_score_loss': {'value': 0.20342857142857143}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8020820708924987},
#       'balanced_acc_error': {'value': 0.015752334045429407},
#       'selection_rate': {'value': 0.34085714285714286},
#       'false_positive_rate': {'value': 0.20776841333821913},
#       'false_positive_error': {'value': 0.015221944778951014},
#       'false_negative_rate': {'value': 0.1880674448767834},
#       'false_negative_error': {'value': 0.027583265010903687},
#       'true_positive_rate': {'value': 0.8119325551232166},
#       'true_negative_rate': {'value': 0.7922315866617808},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}}}}

# %%
# from fpdf import FPDF
# def convert_json_to_pdf(json_data, pdf_file):
#     pdf = FPDF()
#     pdf.add_page()
#     # Main title
#     pdf.set_font("Arial", "B", 16)
#     pdf.cell(0, 10, "JSON to PDF Conversion", ln=True, align="C")
#     # Subtitle for 'complete' section
#     pdf.set_font("Arial", "B", 12)
#     pdf.cell(0, 10, "Complete Data", ln=True, align="L")
#     pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#     # Add key-value pairs for 'complete' section

#     pdf.set_font("Arial", "", 10)
#     for key, value in json_data['complete'].items():
#         print(key, value)
#         pdf.cell(0, 10, f"{key}: {value}", ln=True, align="L")

#     # Subtitle for 'subsets' section
#     pdf.set_font("Arial", "B", 12)
#     pdf.cell(0, 10, "Subsets Data", ln=True, align="L")
#     pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#     # Iterate over 'subsets' data
#     for subset_key, subset_value in json_data['subsets'].items():
#         # Add subtitle for subset
#         pdf.set_font("Arial", "B", 10)
#         pdf.cell(0, 10, subset_key.capitalize(), ln=True, align="L")
#         pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#         # Add key-value pairs for subset section
#         pdf.set_font("Arial", "", 10)
#         for key, value in subset_value.items():
#             pdf.cell(0, 10, f"{key}: {value}", ln=True, align="L")
#         pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#     # Save PDF file
#     pdf.output(pdf_file)
# # Example usage
# json_data = {
#     'complete': {
#         'accuracy': 0.7971428571428572,
#         'precision': 0.5270081164287713,
#         # rest of the data...
#     },
#     'subsets': {
#         'female': {
#             'accuracy': 0.7492890995260664,
#             # rest of the data...
#         },
#         'male': {
#             'accuracy': 0.8697841726618705,
#             # rest of the data...
#         }
#     }
# }
# convert_json_to_pdf(json_data, "output_test.pdf")

# %%
# import json
# from fpdf import FPDF

# with open("values.json") as temp:
#     v = json.load(temp)
#     v = json.loads(v)



# def convert_json_to_pdf(json_data, pdf_file):
#     pdf = FPDF()
#     pdf.add_page()
#     # Main title
#     pdf.set_font("Arial", "B", 16)
#     pdf.cell(0, 10, "pureml-evaluate report", ln=True, align="C")

#     # Subtitle for 'complete' section
#     pdf.set_font("Arial", "B", 14)
#     pdf.cell(0, 10, "Complete Data", ln=True, align="L")
#     pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#     # Add key-value pairs for 'complete' section


#     for metric_group_key, metric_group_value in json_data['complete'].items():
#         # print(key, value)

#         pdf.set_font("Arial", "B", 12)
#         pdf.cell(0, 10, str(metric_group_key.capitalize()), ln=True, align="L")
#         # pdf.cell(0, 10, "", ln=True, align="L")  # Empty line

#         for metric_key, metric_value in metric_group_value.items():
#             pdf.set_font("Arial", "", 10)
#             metric_key = metric_key.replace("_", " ")
#             metric_key = metric_key.capitalize()
#             pdf.cell(0, 10, f"{metric_key.capitalize()}: {metric_value}", ln=True, align="L")

        
#     # pdf.page_break_trigger
#     pdf.add_page()
#     # pdf.cell(0, 10, "", ln=True, align="L")  # Empty line

#     # Subtitle for 'subsets' section
#     pdf.set_font("Arial", "B", 14)
#     pdf.cell(0, 10, "Subsets", ln=True, align="L")
#     pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
#     # Iterate over 'subsets' data
#     for subset_key, subset_value in json_data['subsets'].items():
#         # Add subtitle for subset
#         pdf.set_font("Arial", "B", 12)
#         pdf.cell(0, 10, f"Subset:  {subset_key.capitalize()}", ln=True, align="L")
#         pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
        

#         for metric_group_key, metric_group_value in subset_value.items():         
#             # Add key-value pairs for subset section
        
#             pdf.set_font("Arial", "B", 12)
#             pdf.cell(0, 10, str(metric_group_key.capitalize()), ln=True, align="L")

#             for metric_key, metric_value in metric_group_value.items():
#                 pdf.set_font("Arial", "", 10)
#                 metric_key = metric_key.replace("_", " ")
#                 metric_key = metric_key.capitalize()
#                 pdf.cell(0, 10, f"{metric_key}: {metric_value}", ln=True, align="L")
#             pdf.cell(0, 10, "", ln=True, align="L")  # Empty line
        
#         pdf.add_page()

#     # Save PDF file
#     pdf.output(pdf_file)


# convert_json_to_pdf(v, "output.pdf")

# %%
v
# Out:
# {'complete': {'performance': {'accuracy': {'value': 0.7971428571428572},
#    'precision': {'value': 0.5270081164287713},
#    'recall': {'value': 0.8105897546276367},
#    'f1': {'value': 0.6387381275440978},
#    'balanced_accuracy_score': {'value': 0.801956244563421},
#    'top_k_accuracy_score': {'value': 1.0},
#    'log_loss': {'value': 7.311712544649479},
#    'average_precision_score': {'value': 0.46909214168753266},
#    'roc_auc': {'value': 0.8019562445634209},
#    'brier_score_loss': {'value': 0.20285714285714285}},
#   'fairness': {'SEX': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.058073351745144164},
#     'demographic_parity_ratio': {'value': 0.8401720362840163},
#     'equalized_odds_difference': {'value': 0.12304095990295033},
#     'equalized_odds_ratio': {'value': 0.5170472645574502},
#     'true_positive_parity': {'value': 0.11047349698537057},
#     'false_positive_parity': {'value': 0.12304095990295033},
#     'predictive_value_parity': {'value': 0.2210242836162437}},
#    'Race': {'balanced_accuracy': {'value': 0.801956244563421},
#     'balanced_acc_error': {'value': 0.00909578148026159},
#     'selection_rate': {'value': 0.3402857142857143},
#     'false_positive_rate': {'value': 0.2066772655007949},
#     'false_positive_error': {'value': 0.0087766822602419},
#     'false_negative_rate': {'value': 0.1894102453723633},
#     'false_negative_error': {'value': 0.015934328082772554},
#     'true_positive_rate': {'value': 0.8105897546276367},
#     'true_negative_rate': {'value': 0.7933227344992051},
#     'demographic_parity_difference': {'value': 0.013714285714285734},
#     'demographic_parity_ratio': {'value': 0.9604612850082371},
#     'equalized_odds_difference': {'value': 0.015959537151590153},
#     'equalized_odds_ratio': {'value': 0.9254673161889656},
#     'true_positive_parity': {'value': 0.00374841190071018},
#     'false_positive_parity': {'value': 0.015959537151590153},
#     'predictive_value_parity': {'value': 0.01542750246551805}}}},
#  'subsets': {'SEX': {'female': {'performance': {'accuracy': {'value': 0.7492890995260664},
#      'precision': {'value': 0.4482608695652174},
#      'recall': {'value': 0.7642698295033358},
#      'f1': {'value': 0.5650863250205536},
#      'balanced_accuracy_score': {'value': 0.7547508553258497},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 9.036536797555911},
#      'average_precision_score': {'value': 0.3928292251802703},
#      'roc_auc': {'value': 0.7547508553258497},
#      'brier_score_loss': {'value': 0.25071090047393363}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7547508553258497},
#       'balanced_acc_error': {'value': 0.01284020550193306},
#       'selection_rate': {'value': 0.36334913112164297},
#       'false_positive_rate': {'value': 0.2547681188516362},
#       'false_positive_error': {'value': 0.01210085490514792},
#       'false_negative_rate': {'value': 0.2357301704966642},
#       'false_negative_error': {'value': 0.022650669303401295},
#       'true_positive_rate': {'value': 0.7642698295033358},
#       'true_negative_rate': {'value': 0.7452318811483638},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'male': {'performance': {'accuracy': {'value': 0.8697841726618705},
#      'precision': {'value': 0.6692851531814611},
#      'recall': {'value': 0.8747433264887063},
#      'f1': {'value': 0.7583444592790386},
#      'balanced_accuracy_score': {'value': 0.8715080837700102},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 4.693454146352666},
#      'average_precision_score': {'value': 0.6147093159876752},
#      'roc_auc': {'value': 0.8715080837700102},
#      'brier_score_loss': {'value': 0.1302158273381295}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8715080837700102},
#       'balanced_acc_error': {'value': 0.011933454584385012},
#       'selection_rate': {'value': 0.3052757793764988},
#       'false_positive_rate': {'value': 0.13172715894868586},
#       'false_positive_error': {'value': 0.011725151341348909},
#       'false_negative_rate': {'value': 0.12525667351129363},
#       'false_negative_error': {'value': 0.020788222129195715},
#       'true_positive_rate': {'value': 0.8747433264887063},
#       'true_negative_rate': {'value': 0.8682728410513142},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}},
#   'Race': {'African': {'performance': {'accuracy': {'value': 0.804},
#      'precision': {'value': 0.5360205831903945},
#      'recall': {'value': 0.8116883116883117},
#      'f1': {'value': 0.6456611570247933},
#      'balanced_accuracy_score': {'value': 0.8067599067599067},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.064556064266962},
#      'average_precision_score': {'value': 0.47651021362856694},
#      'roc_auc': {'value': 0.8067599067599068},
#      'brier_score_loss': {'value': 0.196}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8067599067599067},
#       'balanced_acc_error': {'value': 0.015701768766110395},
#       'selection_rate': {'value': 0.33314285714285713},
#       'false_positive_rate': {'value': 0.19816849816849816},
#       'false_positive_error': {'value': 0.014953181822692408},
#       'false_negative_rate': {'value': 0.18831168831168832},
#       'false_negative_error': {'value': 0.027614932969592762},
#       'true_positive_rate': {'value': 0.8116883116883117},
#       'true_negative_rate': {'value': 0.8018315018315019},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'American': {'performance': {'accuracy': {'value': 0.7908571428571428},
#      'precision': {'value': 0.5205930807248764},
#      'recall': {'value': 0.8081841432225064},
#      'f1': {'value': 0.6332665330661322},
#      'balanced_accuracy_score': {'value': 0.7970280539512091},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.538272651666788},
#      'average_precision_score': {'value': 0.46359221577034226},
#      'roc_auc': {'value': 0.7970280539512091},
#      'brier_score_loss': {'value': 0.20914285714285713}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.7970280539512091},
#       'balanced_acc_error': {'value': 0.015806603552970235},
#       'selection_rate': {'value': 0.34685714285714286},
#       'false_positive_rate': {'value': 0.2141280353200883},
#       'false_positive_error': {'value': 0.015422117557001415},
#       'false_negative_rate': {'value': 0.1918158567774936},
#       'false_negative_error': {'value': 0.027596252527854463},
#       'true_positive_rate': {'value': 0.8081841432225064},
#       'true_negative_rate': {'value': 0.7858719646799117},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}},
#    'Indian': {'performance': {'accuracy': {'value': 0.7965714285714286},
#      'precision': {'value': 0.5247275775356245},
#      'recall': {'value': 0.8119325551232166},
#      'f1': {'value': 0.6374745417515275},
#      'balanced_accuracy_score': {'value': 0.8020820708924987},
#      'top_k_accuracy_score': {'value': 1.0},
#      'log_loss': {'value': 7.33230891801469},
#      'average_precision_score': {'value': 0.46747197420068676},
#      'roc_auc': {'value': 0.8020820708924987},
#      'brier_score_loss': {'value': 0.20342857142857143}},
#     'fairness': {'sensitive_column_1': {'balanced_accuracy': {'value': 0.8020820708924987},
#       'balanced_acc_error': {'value': 0.015752334045429407},
#       'selection_rate': {'value': 0.34085714285714286},
#       'false_positive_rate': {'value': 0.20776841333821913},
#       'false_positive_error': {'value': 0.015221944778951014},
#       'false_negative_rate': {'value': 0.1880674448767834},
#       'false_negative_error': {'value': 0.027583265010903687},
#       'true_positive_rate': {'value': 0.8119325551232166},
#       'true_negative_rate': {'value': 0.7922315866617808},
#       'demographic_parity_difference': {'value': 0.0},
#       'demographic_parity_ratio': {'value': 1.0},
#       'equalized_odds_difference': {'value': 0.0},
#       'equalized_odds_ratio': {'value': 1.0},
#       'true_positive_parity': {'value': 0.0},
#       'false_positive_parity': {'value': 0.0},
#       'predictive_value_parity': {'value': 0.0}}}}}}}
